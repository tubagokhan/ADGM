# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/ADGM/blob/main/TestSubTask2EvaluationV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import numpy as np
from nltk.tokenize import sent_tokenize
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

import nltk
nltk.download('punkt')

def calculate_mean_entailment_prob(Answer, Premise):
    # Tokenize both the Answer and Premise texts into sentences
    Hypotheses = sent_tokenize(Answer)
    Premises = sent_tokenize(Premise)

    # Load the NLI model and tokenizer
    model = AutoModelForSequenceClassification.from_pretrained('cross-encoder/nli-deberta-v3-xsmall')
    tokenizer = AutoTokenizer.from_pretrained('cross-encoder/nli-deberta-v3-xsmall')

    # Initialize an empty matrix to store entailment probabilities
    entailment_matrix = []

    for premise in Premises:
        row_probs = []
        for hypothesis in Hypotheses:
            # Prepare the premise-hypothesis pair and tokenize
            pair = [(premise, hypothesis)]
            features = tokenizer(pair, padding=True, truncation=True, return_tensors="pt")

            # Model evaluation
            model.eval()
            with torch.no_grad():
                logits = model(**features).logits
                probs = torch.softmax(logits, dim=1)
                entailment_prob = probs[:, 1].item()  # Extract the entailment probability for this pair
                row_probs.append(entailment_prob)

        # Add the row of entailment probabilities for this premise to the matrix
        entailment_matrix.append(row_probs)

    # Convert the matrix to a NumPy array for easier manipulation
    entailment_matrix_np = np.array(entailment_matrix)

    # Check if the matrix is not empty
    if entailment_matrix_np.size > 0:
        # Reduce the matrix to a one-dimensional vector by taking the max value of each column
        max_entailment_vector = np.max(entailment_matrix_np, axis=0)

        # Calculate the mean of the reduced vector to get the final model score
        final_model_score = np.mean(max_entailment_vector)
    else:
        # Handle the empty matrix case (e.g., by setting the score to a default value)
        final_model_score = 0  # Or any other default value that makes sense

    print("Final Model Score:", final_model_score)

    return final_model_score



def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

def save_json(data, file_path):
    with open(file_path, 'w') as file:
        json.dump(data, file, indent=4)

def find_match(question_id, document):
    for entry in document:
        if entry["QuestionID"] == question_id:
            return entry
    return None


def process_documents_reference_free(input_document, output_path):

    # Load the input document which contains all the necessary information
    document = load_json(input_document)

    results = []
    total_items = len(document)
    item_counter = 0

    # Iterate through each item in the document
    for item in document:
        item_counter += 1
        print(f"Processing item {item_counter} of {total_items}...")

        # Calculate the model score only if both "Answer" and "RetrievedPassage" are present
        if "Answer" in item and "RetrievedPassage" in item:
          # Answer - hypothesis    RetrievedPassage is Premise
            model_score = calculate_mean_entailment_prob(item["Answer"], item["RetrievedPassage"])
            # Add the model score as a new item to the current entry
            item["Model_Score_of_RetrievedPassage_to_Answer"] = model_score
        else:
            print(f"Missing 'Answer' or 'RetrievedPassage' for item {item_counter}")
            # If either is missing, set the model score to None
            item["Model_Score_of_RetrievedPassage(P)_to_Answer(H)"] = None

        # Append the updated item to the results list
        results.append(item)

    # Save the updated results to the specified output path
    save_json(results, output_path)
    print("Processing complete.")



def process_documents_from_source(silver_standarts, participants_answers, output_path):
    silvers = load_json(silver_standarts)
    answers = load_json(participants_answers)

    results = []
    total_items = len(silvers)  # Focus on the first 5 items from silver standards

    item_counter = 0

    for silver in silvers:  # Process only the first 5 items
        item_counter += 1
        print(f"Processing item {item_counter} of {total_items}...")

        match = find_match(silver["QuestionID"], answers)
        print(silver["QuestionID"])
        print(silver["Passage"])
        print(match)
        if match:
          # Answer - hypothesis    Passage is Premise
            # Calculate model_score and add it directly to the matched participant answer item
            model_score = calculate_mean_entailment_prob(match["Answer"], silver["Passage"])
            match["Model_Score_of_SilverPassage(P)_to_Answer(H)"] = model_score
            results.append(match)  # Append the updated participant answer item to results
        else:
            print(f"No match found for QuestionID: {silver['QuestionID']}")
            # Optionally handle the case where no match is found

    save_json(results, output_path)
    print("Processing complete.")



# Set the file paths
silver_standarts = "/content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/SharedTask/COBS_VER15.150823_entailed_questions.json"
participants_answers = "/content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/SharedTask/retrieval_results.hierarchical_bm25_updated.json"
results = "/content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/SharedTask/retrieval_results.hierarchical_bm25_updated_subtask2_results.json"

# Execute the processing

process_documents_reference_free(participants_answers, results)

process_documents_from_source(silver_standarts, participants_answers, results)
# Out:
# Processing item 1 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1
# Processing item 2 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 2
# Processing item 3 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 3
# Processing item 4 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 4
# Processing item 5 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 5
# Processing item 6 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 6
# Processing item 7 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 7
# Processing item 8 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 8
# Processing item 9 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 9
# Processing item 10 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 10
# Processing item 11 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 11
# Processing item 12 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 12
# Processing item 13 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 13
# Processing item 14 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 14
# Processing item 15 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 15
# Processing item 16 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 16
# Processing item 17 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 17
# Processing item 18 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 18
# Processing item 19 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 19
# Processing item 20 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 20
# Processing item 21 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 21
# Processing item 22 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 22
# Processing item 23 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 23
# Processing item 24 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 24
# Processing item 25 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 25
# Processing item 26 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 26
# Processing item 27 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 27
# Processing item 28 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 28
# Processing item 29 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 29
# Processing item 30 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 30
# Processing item 31 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 31
# Processing item 32 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 32
# Processing item 33 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 33
# Processing item 34 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 34
# Processing item 35 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 35
# Processing item 36 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 36
# Processing item 37 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 37
# Processing item 38 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 38
# Processing item 39 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 39
# Processing item 40 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 40
# Processing item 41 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 41
# Processing item 42 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 42
# Processing item 43 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 43
# Processing item 44 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 44
# Processing item 45 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 45
# Processing item 46 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 46
# Processing item 47 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 47
# Processing item 48 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 48
# Processing item 49 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 49
# Processing item 50 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 50
# Processing item 51 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 51
# Processing item 52 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 52
# Processing item 53 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 53
# Processing item 54 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 54
# Processing item 55 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 55
# Processing item 56 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 56
# Processing item 57 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 57
# Processing item 58 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 58
# Processing item 59 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 59
# Processing item 60 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 60
# Processing item 61 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 61
# Processing item 62 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 62
# Processing item 63 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 63
# Processing item 64 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 64
# Processing item 65 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 65
# Processing item 66 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 66
# Processing item 67 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 67
# Processing item 68 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 68
# Processing item 69 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 69
# Processing item 70 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 70
# Processing item 71 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 71
# Processing item 72 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 72
# Processing item 73 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 73
# Processing item 74 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 74
# Processing item 75 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 75
# Processing item 76 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 76
# Processing item 77 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 77
# Processing item 78 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 78
# Processing item 79 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 79
# Processing item 80 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 80
# Processing item 81 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 81
# Processing item 82 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 82
# Processing item 83 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 83
# Processing item 84 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 84
# Processing item 85 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 85
# Processing item 86 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 86
# Processing item 87 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 87
# Processing item 88 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 88
# Processing item 89 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 89
# Processing item 90 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 90
# Processing item 91 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 91
# Processing item 92 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 92
# Processing item 93 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 93
# Processing item 94 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 94
# Processing item 95 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 95
# Processing item 96 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 96
# Processing item 97 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 97
# Processing item 98 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 98
# Processing item 99 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 99
# Processing item 100 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 100
# Processing item 101 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 101
# Processing item 102 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 102
# Processing item 103 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 103
# Processing item 104 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 104
# Processing item 105 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 105
# Processing item 106 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 106
# Processing item 107 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 107
# Processing item 108 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 108
# Processing item 109 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 109
# Processing item 110 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 110
# Processing item 111 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 111
# Processing item 112 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 112
# Processing item 113 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 113
# Processing item 114 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 114
# Processing item 115 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 115
# Processing item 116 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 116
# Processing item 117 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 117
# Processing item 118 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 118
# Processing item 119 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 119
# Processing item 120 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 120
# Processing item 121 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 121
# Processing item 122 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 122
# Processing item 123 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 123
# Processing item 124 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 124
# Processing item 125 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 125
# Processing item 126 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 126
# Processing item 127 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 127
# Processing item 128 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 128
# Processing item 129 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 129
# Processing item 130 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 130
# Processing item 131 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 131
# Processing item 132 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 132
# Processing item 133 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 133
# Processing item 134 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 134
# Processing item 135 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 135
# Processing item 136 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 136
# Processing item 137 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 137
# Processing item 138 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 138
# Processing item 139 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 139
# Processing item 140 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 140
# Processing item 141 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 141
# Processing item 142 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 142
# Processing item 143 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 143
# Processing item 144 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 144
# Processing item 145 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 145
# Processing item 146 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 146
# Processing item 147 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 147
# Processing item 148 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 148
# Processing item 149 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 149
# Processing item 150 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 150
# Processing item 151 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 151
# Processing item 152 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 152
# Processing item 153 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 153
# Processing item 154 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 154
# Processing item 155 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 155
# Processing item 156 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 156
# Processing item 157 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 157
# Processing item 158 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 158
# Processing item 159 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 159
# Processing item 160 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 160
# Processing item 161 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 161
# Processing item 162 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 162
# Processing item 163 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 163
# Processing item 164 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 164
# Processing item 165 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 165
# Processing item 166 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 166
# Processing item 167 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 167
# Processing item 168 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 168
# Processing item 169 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 169
# Processing item 170 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 170
# Processing item 171 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 171
# Processing item 172 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 172
# Processing item 173 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 173
# Processing item 174 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 174
# Processing item 175 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 175
# Processing item 176 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 176
# Processing item 177 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 177
# Processing item 178 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 178
# Processing item 179 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 179
# Processing item 180 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 180
# Processing item 181 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 181
# Processing item 182 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 182
# Processing item 183 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 183
# Processing item 184 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 184
# Processing item 185 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 185
# Processing item 186 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 186
# Processing item 187 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 187
# Processing item 188 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 188
# Processing item 189 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 189
# Processing item 190 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 190
# Processing item 191 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 191
# Processing item 192 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 192
# Processing item 193 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 193
# Processing item 194 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 194
# Processing item 195 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 195
# Processing item 196 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 196
# Processing item 197 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 197
# Processing item 198 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 198
# Processing item 199 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 199
# Processing item 200 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 200
# Processing item 201 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 201
# Processing item 202 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 202
# Processing item 203 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 203
# Processing item 204 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 204
# Processing item 205 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 205
# Processing item 206 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 206
# Processing item 207 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 207
# Processing item 208 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 208
# Processing item 209 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 209
# Processing item 210 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 210
# Processing item 211 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 211
# Processing item 212 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 212
# Processing item 213 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 213
# Processing item 214 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 214
# Processing item 215 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 215
# Processing item 216 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 216
# Processing item 217 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 217
# Processing item 218 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 218
# Processing item 219 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 219
# Processing item 220 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 220
# Processing item 221 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 221
# Processing item 222 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 222
# Processing item 223 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 223
# Processing item 224 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 224
# Processing item 225 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 225
# Processing item 226 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 226
# Processing item 227 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 227
# Processing item 228 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 228
# Processing item 229 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 229
# Processing item 230 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 230
# Processing item 231 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 231
# Processing item 232 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 232
# Processing item 233 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 233
# Processing item 234 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 234
# Processing item 235 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 235
# Processing item 236 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 236
# Processing item 237 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 237
# Processing item 238 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 238
# Processing item 239 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 239
# Processing item 240 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 240
# Processing item 241 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 241
# Processing item 242 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 242
# Processing item 243 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 243
# Processing item 244 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 244
# Processing item 245 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 245
# Processing item 246 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 246
# Processing item 247 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 247
# Processing item 248 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 248
# Processing item 249 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 249
# Processing item 250 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 250
# Processing item 251 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 251
# Processing item 252 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 252
# Processing item 253 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 253
# Processing item 254 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 254
# Processing item 255 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 255
# Processing item 256 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 256
# Processing item 257 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 257
# Processing item 258 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 258
# Processing item 259 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 259
# Processing item 260 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 260
# Processing item 261 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 261
# Processing item 262 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 262
# Processing item 263 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 263
# Processing item 264 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 264
# Processing item 265 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 265
# Processing item 266 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 266
# Processing item 267 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 267
# Processing item 268 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 268
# Processing item 269 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 269
# Processing item 270 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 270
# Processing item 271 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 271
# Processing item 272 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 272
# Processing item 273 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 273
# Processing item 274 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 274
# Processing item 275 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 275
# Processing item 276 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 276
# Processing item 277 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 277
# Processing item 278 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 278
# Processing item 279 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 279
# Processing item 280 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 280
# Processing item 281 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 281
# Processing item 282 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 282
# Processing item 283 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 283
# Processing item 284 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 284
# Processing item 285 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 285
# Processing item 286 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 286
# Processing item 287 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 287
# Processing item 288 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 288
# Processing item 289 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 289
# Processing item 290 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 290
# Processing item 291 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 291
# Processing item 292 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 292
# Processing item 293 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 293
# Processing item 294 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 294
# Processing item 295 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 295
# Processing item 296 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 296
# Processing item 297 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 297
# Processing item 298 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 298
# Processing item 299 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 299
# Processing item 300 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 300
# Processing item 301 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 301
# Processing item 302 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 302
# Processing item 303 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 303
# Processing item 304 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 304
# Processing item 305 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 305
# Processing item 306 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 306
# Processing item 307 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 307
# Processing item 308 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 308
# Processing item 309 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 309
# Processing item 310 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 310
# Processing item 311 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 311
# Processing item 312 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 312
# Processing item 313 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 313
# Processing item 314 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 314
# Processing item 315 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 315
# Processing item 316 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 316
# Processing item 317 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 317
# Processing item 318 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 318
# Processing item 319 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 319
# Processing item 320 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 320
# Processing item 321 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 321
# Processing item 322 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 322
# Processing item 323 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 323
# Processing item 324 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 324
# Processing item 325 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 325
# Processing item 326 of 1518...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Missing 'Answer' or 'RetrievedPassage' for item 326
# Processing item 327 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 327
# Processing item 328 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 328
# Processing item 329 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 329
# Processing item 330 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 330
# Processing item 331 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 331
# Processing item 332 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 332
# Processing item 333 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 333
# Processing item 334 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 334
# Processing item 335 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 335
# Processing item 336 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 336
# Processing item 337 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 337
# Processing item 338 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 338
# Processing item 339 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 339
# Processing item 340 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 340
# Processing item 341 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 341
# Processing item 342 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 342
# Processing item 343 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 343
# Processing item 344 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 344
# Processing item 345 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 345
# Processing item 346 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 346
# Processing item 347 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 347
# Processing item 348 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 348
# Processing item 349 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 349
# Processing item 350 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 350
# Processing item 351 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 351
# Processing item 352 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 352
# Processing item 353 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 353
# Processing item 354 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 354
# Processing item 355 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 355
# Processing item 356 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 356
# Processing item 357 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 357
# Processing item 358 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 358
# Processing item 359 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 359
# Processing item 360 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 360
# Processing item 361 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 361
# Processing item 362 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 362
# Processing item 363 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 363
# Processing item 364 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 364
# Processing item 365 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 365
# Processing item 366 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 366
# Processing item 367 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 367
# Processing item 368 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 368
# Processing item 369 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 369
# Processing item 370 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 370
# Processing item 371 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 371
# Processing item 372 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 372
# Processing item 373 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 373
# Processing item 374 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 374
# Processing item 375 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 375
# Processing item 376 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 376
# Processing item 377 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 377
# Processing item 378 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 378
# Processing item 379 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 379
# Processing item 380 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 380
# Processing item 381 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 381
# Processing item 382 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 382
# Processing item 383 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 383
# Processing item 384 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 384
# Processing item 385 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 385
# Processing item 386 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 386
# Processing item 387 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 387
# Processing item 388 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 388
# Processing item 389 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 389
# Processing item 390 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 390
# Processing item 391 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 391
# Processing item 392 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 392
# Processing item 393 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 393
# Processing item 394 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 394
# Processing item 395 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 395
# Processing item 396 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 396
# Processing item 397 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 397
# Processing item 398 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 398
# Processing item 399 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 399
# Processing item 400 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 400
# Processing item 401 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 401
# Processing item 402 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 402
# Processing item 403 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 403
# Processing item 404 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 404
# Processing item 405 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 405
# Processing item 406 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 406
# Processing item 407 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 407
# Processing item 408 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 408
# Processing item 409 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 409
# Processing item 410 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 410
# Processing item 411 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 411
# Processing item 412 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 412
# Processing item 413 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 413
# Processing item 414 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 414
# Processing item 415 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 415
# Processing item 416 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 416
# Processing item 417 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 417
# Processing item 418 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 418
# Processing item 419 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 419
# Processing item 420 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 420
# Processing item 421 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 421
# Processing item 422 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 422
# Processing item 423 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 423
# Processing item 424 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 424
# Processing item 425 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 425
# Processing item 426 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 426
# Processing item 427 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 427
# Processing item 428 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 428
# Processing item 429 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 429
# Processing item 430 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 430
# Processing item 431 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 431
# Processing item 432 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 432
# Processing item 433 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 433
# Processing item 434 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 434
# Processing item 435 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 435
# Processing item 436 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 436
# Processing item 437 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 437
# Processing item 438 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 438
# Processing item 439 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 439
# Processing item 440 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 440
# Processing item 441 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 441
# Processing item 442 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 442
# Processing item 443 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 443
# Processing item 444 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 444
# Processing item 445 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 445
# Processing item 446 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 446
# Processing item 447 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 447
# Processing item 448 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 448
# Processing item 449 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 449
# Processing item 450 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 450
# Processing item 451 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 451
# Processing item 452 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 452
# Processing item 453 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 453
# Processing item 454 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 454
# Processing item 455 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 455
# Processing item 456 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 456
# Processing item 457 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 457
# Processing item 458 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 458
# Processing item 459 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 459
# Processing item 460 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 460
# Processing item 461 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 461
# Processing item 462 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 462
# Processing item 463 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 463
# Processing item 464 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 464
# Processing item 465 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 465
# Processing item 466 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 466
# Processing item 467 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 467
# Processing item 468 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 468
# Processing item 469 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 469
# Processing item 470 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 470
# Processing item 471 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 471
# Processing item 472 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 472
# Processing item 473 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 473
# Processing item 474 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 474
# Processing item 475 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 475
# Processing item 476 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 476
# Processing item 477 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 477
# Processing item 478 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 478
# Processing item 479 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 479
# Processing item 480 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 480
# Processing item 481 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 481
# Processing item 482 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 482
# Processing item 483 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 483
# Processing item 484 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 484
# Processing item 485 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 485
# Processing item 486 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 486
# Processing item 487 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 487
# Processing item 488 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 488
# Processing item 489 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 489
# Processing item 490 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 490
# Processing item 491 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 491
# Processing item 492 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 492
# Processing item 493 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 493
# Processing item 494 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 494
# Processing item 495 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 495
# Processing item 496 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 496
# Processing item 497 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 497
# Processing item 498 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 498
# Processing item 499 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 499
# Processing item 500 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 500
# Processing item 501 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 501
# Processing item 502 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 502
# Processing item 503 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 503
# Processing item 504 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 504
# Processing item 505 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 505
# Processing item 506 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 506
# Processing item 507 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 507
# Processing item 508 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 508
# Processing item 509 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 509
# Processing item 510 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 510
# Processing item 511 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 511
# Processing item 512 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 512
# Processing item 513 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 513
# Processing item 514 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 514
# Processing item 515 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 515
# Processing item 516 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 516
# Processing item 517 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 517
# Processing item 518 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 518
# Processing item 519 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 519
# Processing item 520 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 520
# Processing item 521 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 521
# Processing item 522 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 522
# Processing item 523 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 523
# Processing item 524 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 524
# Processing item 525 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 525
# Processing item 526 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 526
# Processing item 527 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 527
# Processing item 528 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 528
# Processing item 529 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 529
# Processing item 530 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 530
# Processing item 531 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 531
# Processing item 532 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 532
# Processing item 533 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 533
# Processing item 534 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 534
# Processing item 535 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 535
# Processing item 536 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 536
# Processing item 537 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 537
# Processing item 538 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 538
# Processing item 539 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 539
# Processing item 540 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 540
# Processing item 541 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 541
# Processing item 542 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 542
# Processing item 543 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 543
# Processing item 544 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 544
# Processing item 545 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 545
# Processing item 546 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 546
# Processing item 547 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 547
# Processing item 548 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 548
# Processing item 549 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 549
# Processing item 550 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 550
# Processing item 551 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 551
# Processing item 552 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 552
# Processing item 553 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 553
# Processing item 554 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 554
# Processing item 555 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 555
# Processing item 556 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 556
# Processing item 557 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 557
# Processing item 558 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 558
# Processing item 559 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 559
# Processing item 560 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 560
# Processing item 561 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 561
# Processing item 562 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 562
# Processing item 563 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 563
# Processing item 564 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 564
# Processing item 565 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 565
# Processing item 566 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 566
# Processing item 567 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 567
# Processing item 568 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 568
# Processing item 569 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 569
# Processing item 570 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 570
# Processing item 571 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 571
# Processing item 572 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 572
# Processing item 573 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 573
# Processing item 574 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 574
# Processing item 575 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 575
# Processing item 576 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 576
# Processing item 577 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 577
# Processing item 578 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 578
# Processing item 579 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 579
# Processing item 580 of 1518...
# ...
# Missing 'Answer' or 'RetrievedPassage' for item 1392
# Processing item 1393 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1393
# Processing item 1394 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1394
# Processing item 1395 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1395
# Processing item 1396 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1396
# Processing item 1397 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1397
# Processing item 1398 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1398
# Processing item 1399 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1399
# Processing item 1400 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1400
# Processing item 1401 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1401
# Processing item 1402 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1402
# Processing item 1403 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1403
# Processing item 1404 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1404
# Processing item 1405 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1405
# Processing item 1406 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1406
# Processing item 1407 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1407
# Processing item 1408 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1408
# Processing item 1409 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1409
# Processing item 1410 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1410
# Processing item 1411 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1411
# Processing item 1412 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1412
# Processing item 1413 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1413
# Processing item 1414 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1414
# Processing item 1415 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1415
# Processing item 1416 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1416
# Processing item 1417 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1417
# Processing item 1418 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1418
# Processing item 1419 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1419
# Processing item 1420 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1420
# Processing item 1421 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1421
# Processing item 1422 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1422
# Processing item 1423 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1423
# Processing item 1424 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1424
# Processing item 1425 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1425
# Processing item 1426 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1426
# Processing item 1427 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1427
# Processing item 1428 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1428
# Processing item 1429 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1429
# Processing item 1430 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1430
# Processing item 1431 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1431
# Processing item 1432 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1432
# Processing item 1433 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1433
# Processing item 1434 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1434
# Processing item 1435 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1435
# Processing item 1436 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1436
# Processing item 1437 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1437
# Processing item 1438 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1438
# Processing item 1439 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1439
# Processing item 1440 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1440
# Processing item 1441 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1441
# Processing item 1442 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1442
# Processing item 1443 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1443
# Processing item 1444 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1444
# Processing item 1445 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1445
# Processing item 1446 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1446
# Processing item 1447 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1447
# Processing item 1448 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1448
# Processing item 1449 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1449
# Processing item 1450 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1450
# Processing item 1451 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1451
# Processing item 1452 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1452
# Processing item 1453 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1453
# Processing item 1454 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1454
# Processing item 1455 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1455
# Processing item 1456 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1456
# Processing item 1457 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1457
# Processing item 1458 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1458
# Processing item 1459 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1459
# Processing item 1460 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1460
# Processing item 1461 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1461
# Processing item 1462 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1462
# Processing item 1463 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1463
# Processing item 1464 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1464
# Processing item 1465 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1465
# Processing item 1466 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1466
# Processing item 1467 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1467
# Processing item 1468 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1468
# Processing item 1469 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1469
# Processing item 1470 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1470
# Processing item 1471 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1471
# Processing item 1472 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1472
# Processing item 1473 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1473
# Processing item 1474 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1474
# Processing item 1475 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1475
# Processing item 1476 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1476
# Processing item 1477 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1477
# Processing item 1478 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1478
# Processing item 1479 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1479
# Processing item 1480 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1480
# Processing item 1481 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1481
# Processing item 1482 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1482
# Processing item 1483 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1483
# Processing item 1484 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1484
# Processing item 1485 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1485
# Processing item 1486 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1486
# Processing item 1487 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1487
# Processing item 1488 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1488
# Processing item 1489 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1489
# Processing item 1490 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1490
# Processing item 1491 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1491
# Processing item 1492 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1492
# Processing item 1493 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1493
# Processing item 1494 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1494
# Processing item 1495 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1495
# Processing item 1496 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1496
# Processing item 1497 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1497
# Processing item 1498 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1498
# Processing item 1499 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1499
# Processing item 1500 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1500
# Processing item 1501 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1501
# Processing item 1502 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1502
# Processing item 1503 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1503
# Processing item 1504 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1504
# Processing item 1505 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1505
# Processing item 1506 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1506
# Processing item 1507 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1507
# Processing item 1508 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1508
# Processing item 1509 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1509
# Processing item 1510 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1510
# Processing item 1511 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1511
# Processing item 1512 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1512
# Processing item 1513 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1513
# Processing item 1514 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1514
# Processing item 1515 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1515
# Processing item 1516 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1516
# Processing item 1517 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1517
# Processing item 1518 of 1518...
# Missing 'Answer' or 'RetrievedPassage' for item 1518
# Processing complete.
# Processing item 1 of 1518...
# 943rvf
# For the purposes of this chapter, a Person includes any organisation (including outside of the Abu Dhabi Global Market) whether or not it has a separate legal personality.
# {'QuestionID': '943rvf', 'RetrievedPassage': 'Powers, Functions and Objectives Powers, Functions and Objectives of the Regulator The Regulator has such functions and powers as are conferred on it by or under the ADGM Founding Law and any enactment, including these Regulations. The Regulator may do whatever it considers necessary for or in connection with, or reasonably incidental to, performing its functions and exercising its powers.  In performing its functions and exercising its powers, the Regulator shall pursue the following objectives—   to foster and maintain fairness, transparency and efficiency in the Abu Dhabi Global Market; to foster and maintain confidence in the Abu Dhabi Global Market; to ensure that the financial markets in the Abu Dhabi Global Market are supported by safe and efficient infrastructure; to foster and maintain financial stability in the Abu Dhabi Global Market, including the reduction of systemic risk; to promote and enhance the integrity of the Abu Dhabi Global Market Financial System; to prevent, detect and restrain conduct that causes or may cause damage to the reputation of the Abu Dhabi Global Market through appropriate means including the imposition of sanctions; to secure an appropriate degree of protection for direct and indirect users, and prospective users of the Abu Dhabi Global Market; to promote public understanding of the regulation of the Abu Dhabi Global Market; to further the interests of the Abu Dhabi Global Market; to promote the safety and soundness of Authorised Persons and Recognised Bodies; and to pursue any other objectives as the Board may set. In exercising its powers and performing its functions, the Regulator shall take into consideration the following guiding principles— pursuing the objectives of the Abu Dhabi Global Market in so far as it is appropriate and proper for the Regulator to do so; fostering the development of the Abu Dhabi Global Market as an internationally respected financial centre, and the desirability of sustainable growth in the economy of the Emirate of Abu Dhabi; developing the nature of the activities of the Regulator in order to respond to evolving industry needs; the desirability, where applicable, of engaging in regular dialogue with industry participants; cooperating with and providing assistance to regulatory authorities in the U.A.E. and other jurisdictions; minimising the adverse effects of the activities of the Regulator on competition in the financial services industry; the need to use the resources of the Regulator in the most efficient and economical way; the principle that a burden or restriction which is imposed on a person, or on the carrying on of an activity, should be proportionate to the benefits, considered in general terms, which are expected to result from the imposition of that burden or restriction; the desirability where appropriate of the Regulator exercising its functions in a way that recognises differences in the nature, risks and objectives of businesses carried on by different persons subject to requirements imposed by or under these Regulations; the desirability in appropriate cases of the Regulator publishing information relating to persons on whom requirements are imposed by or under these Regulations, or requiring such persons to publish information, as a means of contributing to the advancement by the Regulator of its objectives; the principle that the Regulator should exercise its functions as transparently as possible; and complying with relevant generally accepted principles of good governance. The Chief Executive  Pursuant to the ADGM Founding Law, the Board shall appoint, remove and replace the head of the management of the Regulator.  The head of the management of the Regulator shall have the title of Chief Executive.  The Board must only remove or replace the Chief Executive when the Board and the President of the Appeals Panel agree that there is Just Cause for such removal or replacement.', 'Question': ' ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-0b83c244ff5b> in <cell line: 150>()
#     148 process_documents_reference_free(participants_answers, results)
#     149
# --> 150 process_documents_from_source(silver_standarts, participants_answers, results)
#     151
#     152
#
# <ipython-input-13-0b83c244ff5b> in process_documents_from_source(silver_standarts, participants_answers, output_path)
#     127           # Answer - hypothesis    Passage is Premise
#     128             # Calculate model_score and add it directly to the matched participant answer item
# --> 129             model_score = calculate_mean_entailment_prob(match["Answer"], silver["Passage"])
#     130             match["Model_Score_of_SilverPassage(P)_to_Answer(H)"] = model_score
#     131             results.append(match)  # Append the updated participant answer item to results
#
# KeyError: 'Answer'

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
import json

def calculate_mean_model_score(json_file_path,value):
    # Open and read the JSON file
    with open(json_file_path, 'r') as file:
        data = json.load(file)

    # Extract "Model_Score" values, ensuring they are not None
    model_scores = []
    for item in data:
        if value in item and item[value] is not None:
            model_scores.append(item[value])

    # Calculate the mean of "Model_Score" values
    if model_scores:
        mean_score = sum(model_scores) / len(model_scores)
        return mean_score
    else:
        return "No valid Model_Score values found"

# Replace 'your_json_file.json' with the path to your actual JSON file
mean_model_score = calculate_mean_model_score('/content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/SharedTask/retrieval_results.hierarchical_bm25_updated_subtask2_results.json')


value="Model_Score_of_RetrievedPassage(P)_to_Answer(H)"
print("Mean Model_Score:", mean_model_score,value)

value="Model_Score_of_SilverPassage(P)_to_Answer(H)"
print("Mean Model_Score:", mean_model_score,value)

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
