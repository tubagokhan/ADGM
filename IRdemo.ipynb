# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/ADGM/blob/main/IRdemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls /content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/ADGM-Docs
# Out:
# '~$RA Guidance Questions.docx'		   'FSRA Regulations Questions.docx'
# '~$RA Rulebooks Query Passage Data .docx'  'FSRA Rulebooks'
#  adgm-retrieval-main.zip		   'FSRA Rulebooks Query Passage Data .docx'
# 'FSRA Guidance'				   'FSRA Rulebooks Questions.docx'
# 'FSRA Guidance Questions.docx'		   'FSRA Rulebooks.zip'
# 'FSRA Regulations'

# %%
! cp /content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/ADGM-Docs/adgm-retrieval-main.zip ./

# %%
! cp drive/MyDrive/projects/ADGM/ADGM\ Docs-20240213T090323Z-001.zip ./

# %%
! ls
# Out:
# adgm-retrieval-main.zip  drive	sample_data

# %%
! unzip adgm-retrieval-main.zip
# Out:
# Archive:  adgm-retrieval-main.zip
# 9cb69d7719fe41cc6a2e954169f1425316b18a6c
#    creating: adgm-retrieval-main/
#   inflating: adgm-retrieval-main/.gitignore
#   inflating: adgm-retrieval-main/README.md
#    creating: adgm-retrieval-main/adgm_retrieval/
#  extracting: adgm-retrieval-main/adgm_retrieval/__init__.py
#   inflating: adgm-retrieval-main/adgm_retrieval/dataloader.py
#    creating: adgm-retrieval-main/adgm_retrieval/pipeline/
#  extracting: adgm-retrieval-main/adgm_retrieval/pipeline/__init__.py
#   inflating: adgm-retrieval-main/adgm_retrieval/pipeline/args.py
#   inflating: adgm-retrieval-main/adgm_retrieval/pipeline/base.py
#   inflating: adgm-retrieval-main/adgm_retrieval/pipeline/bm25.py
#   inflating: adgm-retrieval-main/adgm_retrieval/pipeline/fusion.py
#   inflating: adgm-retrieval-main/adgm_retrieval/pipeline/neural.py
#    creating: adgm-retrieval-main/adgm_retrieval/retrievers/
#   inflating: adgm-retrieval-main/adgm_retrieval/retrievers/__init__.py
# ...

# %%
! cd adgm-retrieval-main && pip install .
# Out:
# Processing /content/adgm-retrieval-main
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/stanford-futuredata/ColBERT.git (to revision 21b460a606bed606e8a7fa105ada36b18e8084ec) to /tmp/pip-install-xx1vvdk_/colbert_9fbd475bbabf483e8575b3e014b66d66
#   Running command git clone --filter=blob:none --quiet https://github.com/stanford-futuredata/ColBERT.git /tmp/pip-install-xx1vvdk_/colbert_9fbd475bbabf483e8575b3e014b66d66
#   Running command git rev-parse -q --verify 'sha^21b460a606bed606e8a7fa105ada36b18e8084ec'
#   Running command git fetch -q https://github.com/stanford-futuredata/ColBERT.git 21b460a606bed606e8a7fa105ada36b18e8084ec
#   Running command git checkout -q 21b460a606bed606e8a7fa105ada36b18e8084ec
#   Resolved https://github.com/stanford-futuredata/ColBERT.git to commit 21b460a606bed606e8a7fa105ada36b18e8084ec
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.6 MB/s eta 0:00:00
# ...

# %%
! unzip ADGM\ Docs-20240213T090323Z-001.zip
# Out:
# Archive:  ADGM Docs-20240213T090323Z-001.zip
# replace ADGM Docs/FSRA Regulations/CRS Regulations 2017 (Consolidated_October 2023) v6.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: ADGM Docs/FSRA Regulations/CRS Regulations 2017 (Consolidated_October 2023) v6.json
#   inflating: ADGM Docs/FSRA Regulations/Foreign Tax Account Compliance Regulations 2022.json
#   inflating: ADGM Docs/FSRA Regulations Questions.docx
#   inflating: ADGM Docs/FSRA Regulations/BRR Regulations (December 2018).json
#   inflating: ADGM Docs/FSRA Regulations/FSMR (Consolidated_December 2023).json
#   inflating: ADGM Docs/FSRA Rulebooks/IFR_VER07.181223.json
#   inflating: ADGM Docs/FSRA Rulebooks Questions.docx
#   inflating: ADGM Docs/FSRA Rulebooks/GLO_VER19.181223.json
#   inflating: ADGM Docs/FSRA Rulebooks/FUNDS_VER08.040723.json
#   inflating: ADGM Docs/FSRA Rulebooks/AML_VER09.211223.json
#   inflating: ADGM Docs/FSRA Rulebooks/MKT_VER08.181223.json
# ...

# %%
! ls ADGM\Docs
# Out:
# ls: cannot access 'ADGM Docs': No such file or directory

# %%
! rm -r bm25_document_index
# Out:
# rm: cannot remove 'bm25_document_index': No such file or directory

# %%
! python -m adgm_retrieval.pipeline.neural --retriever=DRAGONPlus --data_path="/content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/ADGM-Docs"
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Loading ADGM documents: 100% 39/39 [00:36<00:00,  1.06it/s]
# [2024-02-27 10:42:34] INFO [root.bm25_index_documents:31] Doing BM25 document indexing over 39 documents
# [2024-02-27 10:42:34] INFO [root.index:49] Run indexing.
# Picked up _JAVA_OPTIONS: -Xmx5g
# Converting to pyserini format: 100% 39/39 [00:00<00:00, 1985.07it/s]
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2024-02-27 10:42:36,453 INFO  [main] index.IndexCollection (IndexCollection.java:380) - Setting log level to INFO
# ...

# %%
import pandas as pd

pd.read_csv("/content/output/2024_02_27_09_49_39.tsv", sep="\t")
# Out:
#    qid       query  rank  score ContextID  \
# 0    0  unitholder     1   0.94    11.0.4
# 1    0  unitholder     2   0.80     6.1.0
# 2    0  unitholder     3   0.78    11.0.1
# 3    0  unitholder     4   0.33     4.2.7
# 4    0  unitholder     5   0.27     7.3.2
# 5    0  unitholder     6   0.22    11.0.3
# 6    0  unitholder     7   0.21     3.6.1
# 7    0  unitholder     8   0.20     5.7.2
# 8    0  unitholder     9   0.20     5.2.6
# 9    0  unitholder    10   0.20     4.2.8
#
#                                              Context  \
# 0  Investment Trusts General prohibition A person...
# 1  This Chapter applies to a Fund Manager and, wh...
# 2  Interpretation Collective Investment Funds In ...
# 3  Obligation relating to making a Prospectus ava...
# 4  (1)\tA Person is hereby prescribed as a Connec...
# 5  Notification Requirement Applicable to \nExemp...
# 6  (1)\tFor the purposes of section 76 of the FSM...
# 7  Where an Insurer is the Parent of a Financial ...
# ...
